# %% [markdown]
# # 1. Import Libraries

# %%
import os
import sys
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # 2. File Paths

# %%
scripts_path = os.path.abspath(os.path.join('..', 'Scripts'))
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

data_dir = os.path.abspath(os.path.join('..', 'Data', 'TrainTest'))
hyperparameter_dir = os.path.abspath(os.path.join('..', 'Data', 'HyperParameters'))
save_dir = os.path.abspath(os.path.join('..', 'Data', 'SavedModels'))
loss_history_dir = os.path.abspath(os.path.join('..', 'Data','LossHistory'))
visualization_dir = os.path.abspath(os.path.join('..', 'Data','Visualization'))

# %% [markdown]
# # 3. Load Models & Data

# %% [markdown]
# ## 1. Data

# %%
# Load matriks rating (data latih)
train_data = np.load(os.path.join(data_dir, 'train_data.npy')).astype(np.float32)

# Mengambil jumlah item (film) untuk layer output VAE
num_items = train_data.shape[1]

# %% [markdown]
# ## 2. Models

# %%
from model_enhanced import Encoder, Decoder, VAE, RSVD, KLAnnealingCallback, CyclicalKLAnnealingCallback

# %% [markdown]
# # 4. Training

# %% [markdown]
# ## 1. VAE

# %% [markdown]
# ### 1. Import Hyperparameters
#     Load hyperparameter terbaik dari Hyperparameter Tuning

# %%
vae_progress_file = os.path.join(hyperparameter_dir, 'tuning_progress_vae_enh.json')
with open(vae_progress_file, 'r') as f:
    best_vae_params = json.load(f)['best_params']

print(f"\n[INFO] Melatih ulang VAE dengan parameter terbaik: {best_vae_params}")
# Out:
# [INFO] Melatih ulang VAE dengan parameter terbaik: {'latent_dim': 200, 'learning_rate': 0.005, 'batch_size': 128, 'dropout_rate': 0.4, 'beta': 0.1, 'cycle_epochs': 15, 'hidden_dims': [512, 256, 128]}

# %% [markdown]
# ### 2. Construct Model

# %%
# Membangun arsitektur Encoder dan Decoder
encoder = Encoder(hidden_dims=best_vae_params['hidden_dims'], latent_dim=best_vae_params['latent_dim'], dropout_rate=best_vae_params['dropout_rate'])
decoder = Decoder(hidden_dims=best_vae_params['hidden_dims'][::-1], output_dim=num_items)

# Inisialisasi VAE dengan beta=0.0 agar KL annealing mulai dari nol
final_vae = VAE(encoder, decoder, beta=0.0, input_dropout_rate=0.5)

# Inisialisasi bobot awal agar tensorflow mengenali dimensi data
_ = final_vae(train_data[:1])

# Kompilasi model dengan optimizer Adam dan learning rate terbaik
# Gradient clipping konsisten dengan saat hyperparameter tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate = best_vae_params['learning_rate'],
    clipnorm      = 1.0
)
final_vae.compile(optimizer=optimizer)

# Jumlah epoch untuk menaikkan beta dari 0 ke beta_target secara linear.
# Nilai 30 dipilih sebagai ~30% dari estimasi epoch konvergensi (88 epoch sebelumnya),
# memberi model cukup waktu untuk mempelajari rekonstruksi sebelum KL mulai dipaksakan.

# Callback KL annealing: naikkan beta bertahap dari 0 → best_vae_params['beta']
kl_annealing = CyclicalKLAnnealingCallback(
    beta_target=best_vae_params['beta'],
    cycle_epochs=best_vae_params['cycle_epochs']
)

# Early stopping agar training berhenti jika loss tidak turun selama 10 iterasi
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='loss', patience=10, restore_best_weights=True, verbose=1
)

# %% [markdown]
# ### 3. Training Model

# %%
# Latih VAE dengan matriks rating asli
history = final_vae.fit(
    train_data, train_data, 
    epochs=500,
    batch_size=best_vae_params['batch_size'], 
    # kl_annealing diletakkan sebelum early_stopping agar beta sudah
    # diperbarui di awal epoch sebelum loss dihitung
    callbacks=[kl_annealing, early_stopping],
    verbose=1 # Tampilkan progress bar untuk melihat pergerakannya
)
# Out:
# Epoch 1/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 144.5882 - loss: 4.1238 - reconstruction_loss: 4.1238  [Cyclical KL] Epoch 1 | Siklus 1 pos 1/15 | beta = 0.000000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - kl_loss: 240.3114 - loss: 4.1001 - reconstruction_loss: 4.1001
# Epoch 2/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 818.8417 - loss: 15.7492 - reconstruction_loss: 4.0515  [Cyclical KL] Epoch 2 | Siklus 1 pos 2/15 | beta = 0.014286 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 410.6782 - loss: 9.9521 - reconstruction_loss: 4.0853
# Epoch 3/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 26.6271 - loss: 4.8653 - reconstruction_loss: 4.1045  [Cyclical KL] Epoch 3 | Siklus 1 pos 3/15 | beta = 0.028571 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 16.8094 - loss: 4.5453 - reconstruction_loss: 4.0650
# Epoch 4/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 5.4700 - loss: 4.3102 - reconstruction_loss: 4.0757  [Cyclical KL] Epoch 4 | Siklus 1 pos 4/15 | beta = 0.042857 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 4.0773 - loss: 4.2298 - reconstruction_loss: 4.0550
# Epoch 5/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 2.0062 - loss: 4.1958 - reconstruction_loss: 4.0812  [Cyclical KL] Epoch 5 | Siklus 1 pos 5/15 | beta = 0.057143 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 1.5681 - loss: 4.1377 - reconstruction_loss: 4.0480
# Epoch 6/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.8933 - loss: 4.1330 - reconstruction_loss: 4.0691  [Cyclical KL] Epoch 6 | Siklus 1 pos 6/15 | beta = 0.071429 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.7303 - loss: 4.1085 - reconstruction_loss: 4.0563
# Epoch 7/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.4414 - loss: 4.0822 - reconstruction_loss: 4.0444  [Cyclical KL] Epoch 7 | Siklus 1 pos 7/15 | beta = 0.085714 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.3666 - loss: 4.0819 - reconstruction_loss: 4.0505
# Epoch 8/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.2569 - loss: 4.0425 - reconstruction_loss: 4.0168  [Cyclical KL] Epoch 8 | Siklus 1 pos 8/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.2138 - loss: 4.0684 - reconstruction_loss: 4.0470
# Epoch 9/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.1587 - loss: 4.0906 - reconstruction_loss: 4.0748  [Cyclical KL] Epoch 9 | Siklus 1 pos 9/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.1395 - loss: 4.0564 - reconstruction_loss: 4.0424
# Epoch 10/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.5496 - loss: 4.1473 - reconstruction_loss: 4.0923  [Cyclical KL] Epoch 10 | Siklus 1 pos 10/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.3869 - loss: 4.0808 - reconstruction_loss: 4.0421
# Epoch 11/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.2079 - loss: 4.0454 - reconstruction_loss: 4.0246  [Cyclical KL] Epoch 11 | Siklus 1 pos 11/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.1808 - loss: 4.0524 - reconstruction_loss: 4.0343
# Epoch 12/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.1143 - loss: 4.0447 - reconstruction_loss: 4.0333  [Cyclical KL] Epoch 12 | Siklus 1 pos 12/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.1011 - loss: 4.0604 - reconstruction_loss: 4.0502
# Epoch 13/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0727 - loss: 4.0241 - reconstruction_loss: 4.0168  [Cyclical KL] Epoch 13 | Siklus 1 pos 13/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0626 - loss: 4.0536 - reconstruction_loss: 4.0474
# Epoch 14/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0503 - loss: 4.0240 - reconstruction_loss: 4.0190  [Cyclical KL] Epoch 14 | Siklus 1 pos 14/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0442 - loss: 4.0452 - reconstruction_loss: 4.0407
# Epoch 15/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0339 - loss: 4.0199 - reconstruction_loss: 4.0165  [Cyclical KL] Epoch 15 | Siklus 1 pos 15/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0315 - loss: 4.0533 - reconstruction_loss: 4.0502
# Epoch 16/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0757 - loss: 4.0102 - reconstruction_loss: 4.0102  [Cyclical KL] Epoch 16 | Siklus 2 pos 1/15 | beta = 0.000000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.2056 - loss: 4.0391 - reconstruction_loss: 4.0391
# Epoch 17/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.3929 - loss: 4.0466 - reconstruction_loss: 4.0409  [Cyclical KL] Epoch 17 | Siklus 2 pos 2/15 | beta = 0.014286 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.2716 - loss: 4.0394 - reconstruction_loss: 4.0355
# Epoch 18/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.1475 - loss: 4.1052 - reconstruction_loss: 4.1010  [Cyclical KL] Epoch 18 | Siklus 2 pos 3/15 | beta = 0.028571 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.1157 - loss: 4.0478 - reconstruction_loss: 4.0445
# Epoch 19/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0671 - loss: 4.0030 - reconstruction_loss: 4.0002  [Cyclical KL] Epoch 19 | Siklus 2 pos 4/15 | beta = 0.042857 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0583 - loss: 4.0318 - reconstruction_loss: 4.0293
# Epoch 20/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0405 - loss: 4.0724 - reconstruction_loss: 4.0701  [Cyclical KL] Epoch 20 | Siklus 2 pos 5/15 | beta = 0.057143 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0356 - loss: 4.0338 - reconstruction_loss: 4.0318
# Epoch 21/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0297 - loss: 4.0624 - reconstruction_loss: 4.0602  [Cyclical KL] Epoch 21 | Siklus 2 pos 6/15 | beta = 0.071429 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0269 - loss: 4.0365 - reconstruction_loss: 4.0346
# Epoch 22/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0242 - loss: 4.0397 - reconstruction_loss: 4.0376  [Cyclical KL] Epoch 22 | Siklus 2 pos 7/15 | beta = 0.085714 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0233 - loss: 4.0445 - reconstruction_loss: 4.0425
# Epoch 23/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0226 - loss: 4.0938 - reconstruction_loss: 4.0915  [Cyclical KL] Epoch 23 | Siklus 2 pos 8/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0247 - loss: 4.0531 - reconstruction_loss: 4.0506
# Epoch 24/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0286 - loss: 4.0136 - reconstruction_loss: 4.0107  [Cyclical KL] Epoch 24 | Siklus 2 pos 9/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0255 - loss: 4.0435 - reconstruction_loss: 4.0409
# Epoch 25/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0300 - loss: 4.0778 - reconstruction_loss: 4.0748  [Cyclical KL] Epoch 25 | Siklus 2 pos 10/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0261 - loss: 4.0479 - reconstruction_loss: 4.0453
# Epoch 26/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0373 - loss: 4.0538 - reconstruction_loss: 4.0500  [Cyclical KL] Epoch 26 | Siklus 2 pos 11/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0324 - loss: 4.0475 - reconstruction_loss: 4.0443
# Epoch 27/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0227 - loss: 4.0385 - reconstruction_loss: 4.0362  [Cyclical KL] Epoch 27 | Siklus 2 pos 12/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0212 - loss: 4.0323 - reconstruction_loss: 4.0302
# Epoch 28/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0250 - loss: 4.0582 - reconstruction_loss: 4.0557  [Cyclical KL] Epoch 28 | Siklus 2 pos 13/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.0227 - loss: 4.0216 - reconstruction_loss: 4.0194
# Epoch 29/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0316 - loss: 4.0325 - reconstruction_loss: 4.0294  [Cyclical KL] Epoch 29 | Siklus 2 pos 14/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0284 - loss: 4.0274 - reconstruction_loss: 4.0246
# Epoch 30/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0300 - loss: 4.0427 - reconstruction_loss: 4.0397  [Cyclical KL] Epoch 30 | Siklus 2 pos 15/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0256 - loss: 4.0304 - reconstruction_loss: 4.0278
# Epoch 31/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.1154 - loss: 4.1061 - reconstruction_loss: 4.1061  [Cyclical KL] Epoch 31 | Siklus 3 pos 1/15 | beta = 0.000000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.3724 - loss: 4.0333 - reconstruction_loss: 4.0333
# Epoch 32/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.5987 - loss: 4.0803 - reconstruction_loss: 4.0717  [Cyclical KL] Epoch 32 | Siklus 3 pos 2/15 | beta = 0.014286 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.3984 - loss: 4.0451 - reconstruction_loss: 4.0394
# Epoch 33/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.1781 - loss: 3.9995 - reconstruction_loss: 3.9944  [Cyclical KL] Epoch 33 | Siklus 3 pos 3/15 | beta = 0.028571 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 0.1384 - loss: 4.0565 - reconstruction_loss: 4.0526
# Epoch 34/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0817 - loss: 4.0804 - reconstruction_loss: 4.0769  [Cyclical KL] Epoch 34 | Siklus 3 pos 4/15 | beta = 0.042857 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0637 - loss: 4.0368 - reconstruction_loss: 4.0341
# Epoch 35/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0480 - loss: 4.0409 - reconstruction_loss: 4.0382  [Cyclical KL] Epoch 35 | Siklus 3 pos 5/15 | beta = 0.057143 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0421 - loss: 4.0411 - reconstruction_loss: 4.0387
# Epoch 36/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0344 - loss: 4.0951 - reconstruction_loss: 4.0927  [Cyclical KL] Epoch 36 | Siklus 3 pos 6/15 | beta = 0.071429 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0287 - loss: 4.0385 - reconstruction_loss: 4.0365
# Epoch 37/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0231 - loss: 4.0924 - reconstruction_loss: 4.0904  [Cyclical KL] Epoch 37 | Siklus 3 pos 7/15 | beta = 0.085714 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0218 - loss: 4.0258 - reconstruction_loss: 4.0240
# Epoch 38/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.0277 - loss: 4.0498 - reconstruction_loss: 4.0470  [Cyclical KL] Epoch 38 | Siklus 3 pos 8/15 | beta = 0.100000 / 0.1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.0361 - loss: 4.0307 - reconstruction_loss: 4.0271
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %% [markdown]
# ### 4. Save Weights
#     Simpan bobot model setelah selesai training

# %%
final_vae.save_weights(os.path.join(save_dir, 'trained_best_vae_weights_enh.weights.h5'))
print("[SUCCESS] Bobot VAE Final berhasil disimpan!")
# Out:
# [SUCCESS] Bobot VAE Final berhasil disimpan!

# %% [markdown]
# ### 5. Save Loss History
#     Simpan riwayat loss untuk visualisasi

# %%
vae_history_dict = {'loss': history.history['loss']}

with open(os.path.join(loss_history_dir, 'final_vae_loss_history_enh.json'), 'w') as f:
    json.dump(vae_history_dict, f)

# %% [markdown]
# ### 6. Latent Matrix Z
#     Get latent matrix from VAE for training RSVD

# %%
# z_mean, _ = final_vae.encoder.predict(train_data, batch_size=best_vae_params['batch_size'])
# latent_matrix_Z_final = z_mean

# %% [markdown]
# ## 2. RSVD

# %% [markdown]
# ### 1. Import Hyperparameters
#     Load hyperparameter terbaik dari Hyperparameter Tuning

# %%
rsvd_progress_file = os.path.join(hyperparameter_dir, 'tuning_progress_rsvd.json')
with open(rsvd_progress_file, 'r') as f:
    best_rsvd_params = json.load(f)['best_params']

print(f"\n[INFO] Melatih ulang RSVD dengan parameter terbaik: {best_rsvd_params}")
# Out:
# [INFO] Melatih ulang RSVD dengan parameter terbaik: {'n_factors': 10, 'learning_rate': 0.005, 'lambda_reg': 0.001}

# %% [markdown]
# ### 2. Construct Model
#     Inisialisasi model RSVD

# %%
final_rsvd = RSVD(
    n_factors=best_rsvd_params['n_factors'], 
    learning_rate=best_rsvd_params['learning_rate'], 
    lambda_reg=best_rsvd_params['lambda_reg'], 
    epochs=100 # Naik drastis agar dekomposisi sempurna
)

# %% [markdown]
# ### 3. Training Model

# %%
# Train dengan data asli
final_rsvd.fit(train_data)

# Mengambil loss dari evaluasi akhir array
final_total_loss = final_rsvd.loss_history[-1]
print(f"Training selesai. Final total loss pada iterasi terakhir: {final_total_loss:.4f}")
# Out:
# [INFO] Total rating     : 80000
# [INFO] Training ratings : 72000
# [INFO] Validation ratings: 8,000
# Epoch 001/100 | Train MSE: 0.040869 | Val MSE: 0.041998 | L2: 0.260719 | Total Loss: 0.301588
# Epoch 002/100 | Train MSE: 0.038213 | Val MSE: 0.039815 | L2: 0.259427 | Total Loss: 0.297639
# Epoch 003/100 | Train MSE: 0.036922 | Val MSE: 0.038810 | L2: 0.258285 | Total Loss: 0.295207
# Epoch 004/100 | Train MSE: 0.036119 | Val MSE: 0.038209 | L2: 0.257270 | Total Loss: 0.293389
# Epoch 005/100 | Train MSE: 0.035555 | Val MSE: 0.037800 | L2: 0.256363 | Total Loss: 0.291919
# Epoch 006/100 | Train MSE: 0.035132 | Val MSE: 0.037501 | L2: 0.255550 | Total Loss: 0.290682
# Epoch 007/100 | Train MSE: 0.034801 | Val MSE: 0.037275 | L2: 0.254818 | Total Loss: 0.289619
# Epoch 008/100 | Train MSE: 0.034534 | Val MSE: 0.037098 | L2: 0.254158 | Total Loss: 0.288692
# Epoch 009/100 | Train MSE: 0.034314 | Val MSE: 0.036957 | L2: 0.253561 | Total Loss: 0.287875
# Epoch 010/100 | Train MSE: 0.034130 | Val MSE: 0.036844 | L2: 0.253021 | Total Loss: 0.287151
# Epoch 011/100 | Train MSE: 0.033973 | Val MSE: 0.036752 | L2: 0.252532 | Total Loss: 0.286505
# Epoch 012/100 | Train MSE: 0.033838 | Val MSE: 0.036676 | L2: 0.252089 | Total Loss: 0.285927
# Epoch 013/100 | Train MSE: 0.033720 | Val MSE: 0.036613 | L2: 0.251688 | Total Loss: 0.285407
# Epoch 014/100 | Train MSE: 0.033615 | Val MSE: 0.036562 | L2: 0.251325 | Total Loss: 0.284940
# Epoch 015/100 | Train MSE: 0.033523 | Val MSE: 0.036519 | L2: 0.250997 | Total Loss: 0.284519
# Epoch 016/100 | Train MSE: 0.033439 | Val MSE: 0.036483 | L2: 0.250701 | Total Loss: 0.284140
# Epoch 017/100 | Train MSE: 0.033364 | Val MSE: 0.036454 | L2: 0.250435 | Total Loss: 0.283799
# Epoch 018/100 | Train MSE: 0.033294 | Val MSE: 0.036429 | L2: 0.250197 | Total Loss: 0.283492
# Epoch 019/100 | Train MSE: 0.033231 | Val MSE: 0.036409 | L2: 0.249986 | Total Loss: 0.283216
# Epoch 020/100 | Train MSE: 0.033171 | Val MSE: 0.036393 | L2: 0.249799 | Total Loss: 0.282970
# Epoch 021/100 | Train MSE: 0.033116 | Val MSE: 0.036380 | L2: 0.249635 | Total Loss: 0.282751
# Epoch 022/100 | Train MSE: 0.033063 | Val MSE: 0.036369 | L2: 0.249494 | Total Loss: 0.282557
# Epoch 023/100 | Train MSE: 0.033013 | Val MSE: 0.036361 | L2: 0.249374 | Total Loss: 0.282387
# Epoch 024/100 | Train MSE: 0.032966 | Val MSE: 0.036356 | L2: 0.249274 | Total Loss: 0.282239
# Epoch 025/100 | Train MSE: 0.032920 | Val MSE: 0.036352 | L2: 0.249193 | Total Loss: 0.282113
# Epoch 026/100 | Train MSE: 0.032875 | Val MSE: 0.036350 | L2: 0.249132 | Total Loss: 0.282008
# Epoch 027/100 | Train MSE: 0.032832 | Val MSE: 0.036349 | L2: 0.249089 | Total Loss: 0.281921
# Epoch 028/100 | Train MSE: 0.032790 | Val MSE: 0.036350 | L2: 0.249065 | Total Loss: 0.281854
# Epoch 029/100 | Train MSE: 0.032748 | Val MSE: 0.036352 | L2: 0.249058 | Total Loss: 0.281806
# Epoch 030/100 | Train MSE: 0.032707 | Val MSE: 0.036356 | L2: 0.249068 | Total Loss: 0.281775
# Epoch 031/100 | Train MSE: 0.032666 | Val MSE: 0.036360 | L2: 0.249095 | Total Loss: 0.281761
# Epoch 032/100 | Train MSE: 0.032625 | Val MSE: 0.036366 | L2: 0.249140 | Total Loss: 0.281765
#
# [Early Stopping] Tidak ada perbaikan Val MSE selama 5 epoch.
# [Early Stopping] Berhenti di epoch 32. Best Val MSE: 0.036349
# Training selesai. Final total loss pada iterasi terakhir: 0.2818

# %% [markdown]
# ### 4. Save Weights
#     Simpan bobot setelah training

# %%
np.save(os.path.join(save_dir, 'final_mu_enh.npy'), np.array(final_rsvd.mu))
np.save(os.path.join(save_dir, 'final_b_u_enh.npy'), final_rsvd.b_u)
np.save(os.path.join(save_dir, 'final_b_i_enh.npy'), final_rsvd.b_i)
np.save(os.path.join(save_dir, 'best_U_enh.npy'), final_rsvd.U)
np.save(os.path.join(save_dir, 'best_Sigma_enh.npy'), final_rsvd.Sigma)
np.save(os.path.join(save_dir, 'best_V_enh.npy'), final_rsvd.V)
print("[SUCCESS] Matriks RSVD Final berhasil disimpan!")
# Out:
# [SUCCESS] Matriks RSVD Final berhasil disimpan!

# %% [markdown]
# ### 5. Save Loss History
#     Simpan riwayat loss untuk visualisasi

# %%
np.save(os.path.join(loss_history_dir, 'final_rsvd_loss_history_enh.npy'), final_rsvd.loss_history)

# %% [markdown]
# # 5. Training Visualization

# %% [markdown]
# ## 1. Import Loss History

# %% [markdown]
# ### 1. VAE

# %%
# Load riwayat loss VAE
try:
    with open(os.path.join(loss_history_dir, 'final_vae_loss_history_enh.json'), 'r') as f:
        vae_loss_history = json.load(f)['loss']

except FileNotFoundError as e:
    print(f"[ERROR] Could not find the history files. Details: {e}")

# %% [markdown]
# ### 2. RSVD

# %%
# Load riwayat loss RSVD
rsvd_loss_history = np.load(os.path.join(loss_history_dir, 'final_rsvd_loss_history_enh.npy'))

# %% [markdown]
# ## 2. Visualization

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), dpi=100)
    
# ==========================================
# PLOT 1: KURVA LOSS VAE
# ==========================================
ax1 = axes[0]
# PERBAIKAN: Mengubah label menjadi (MSE + Beta KL) sesuai modifikasi fungsi loss di proposal
beta_val = best_vae_params.get('beta', 'β')
ax1.plot(vae_loss_history, label=f'Total Loss (MSE + {beta_val} KL)', color='#2ca02c', linewidth=2.5)

# Menandai titik epoch terakhir dengan scatter merah
vae_final_epoch = len(vae_loss_history) - 1
vae_final_loss = vae_loss_history[-1]
ax1.scatter(vae_final_epoch, vae_final_loss, color='red', s=50, zorder=5)
ax1.text(vae_final_epoch, vae_final_loss + (vae_final_loss * 0.02), f'{vae_final_loss:.4f}', 
         ha='right', va='bottom', fontsize=12, fontweight='bold', color='red')
         
ax1.set_title('VAE Final Training Convergence', fontsize=15, fontweight='bold', pad=15)
ax1.set_xlabel('Epochs', fontsize=13)
ax1.set_ylabel('Loss Value', fontsize=13)
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(loc='upper right', fontsize=11)

# ==========================================
# PLOT 2: KURVA MSE RSVD
# ==========================================
ax2 = axes[1]
ax2.plot(rsvd_loss_history, label='Total Loss (MSE + L2 Penalty)', color='#1f77b4', linewidth=2.5)

# Menandai titik epoch terakhir dengan scatter merah
rsvd_final_epoch = len(rsvd_loss_history) - 1
rsvd_final_loss = rsvd_loss_history[-1]
ax2.scatter(rsvd_final_epoch, rsvd_final_loss, color='red', s=50, zorder=5)
ax2.text(rsvd_final_epoch, rsvd_final_loss + (rsvd_final_loss * 0.02), f'{rsvd_final_loss:.6f}', 
         ha='right', va='bottom', fontsize=12, fontweight='bold', color='red')
         
ax2.set_title('RSVD Final Training Convergence', fontsize=15, fontweight='bold', pad=15)
ax2.set_xlabel('Epochs', fontsize=13)
ax2.set_ylabel('Total Loss (MSE + L2 Penalty)', fontsize=13)
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend(loc='upper right', fontsize=11)

# ==========================================
# FINALISASI DAN PENYIMPANAN GAMBAR
# ==========================================
plt.tight_layout()

# Menyimpan gambar dengan resolusi tinggi (300 dpi) agar tajam saat dimasukkan ke PDF/Word Skripsi
timestamp = datetime.now().strftime('%Y%m%d_%H%M')
plot_path = os.path.join(visualization_dir, f'final_training_curves_{timestamp}.png')
plt.savefig(plot_path, dpi=300, bbox_inches='tight')
print(f"\n[SUCCESS] Gambar grafik beresolusi tinggi (High-Res) berhasil disimpan di: {plot_path}")

plt.show()
# Out:
# [SUCCESS] Gambar grafik beresolusi tinggi (High-Res) berhasil disimpan di: c:\Users\USER\Documents\Folder-Proposal\Programs\Data\Visualization\final_training_curves_20260317_1941.png
